# %%
import pandas as pd
import re
import os

# %%
csv_path = r'/home/omen/Documents/VS_data/vs_paths.csv'
data_dir = r'\home\omen\Documents\VS_data'
df = pd.read_csv(csv_path)

# %%
weight_folders = list(df['image_path'])
weight_folders = [os.path.join(data_dir,p) for p in weight_folders]
weight_folders = [p.replace("\\", "/") for p in weight_folders]
len(weight_folders)
# Out:
# 301

# %%
weight_folders[6]
# Out:
# 'D:/VSdata/Vestibular-Schwannoma-MC-RC/VS-SEG-013/12-23-1991-NA-t1of10External Images for PACS-95314/2.000000-T2T2 AXIAL CISS-10876'

# %%
seg_paths = list(df['SegmentationPath'])
seg_paths = [os.path.join(data_dir,p) for p in seg_paths]
seg_paths = [p.replace("\\", "/") for p in seg_paths]
len(seg_paths)
# Out:
# 301

# %%
def extract_patient_name(path):
    pattern = r"/(?P<patient_name>(?:VS-(?:SEG|MC-RC)-)?\d+)/(?P<date_of_mri>\d{2}-\d{2}-\d{4})"
    match = re.search(pattern, path)
    if match:
        return match.group(1)
    return None

def extract_patient_year(path):
  pattern = r"/(?P<patient_name>(?:VS-(?:SEG|MC-RC)-)?\d+)/(?P<date_of_mri>\d{2}-\d{2}-\d{4})"
  match = re.search(pattern, path)
  if match:
    return match.group(2)
  return None

# %%
x = []

for i in range(len(weight_folders)):
# for i in range(6):

    patient_id = extract_patient_name(weight_folders[i])
    if patient_id is None:
        print(f"Warning: Could not extract patient ID from {weight_folders[i]}. Skipping.")
        continue
    
    patient_year = extract_patient_year(weight_folders[i])
    if patient_year is None:
        print(f"Warning: Could not extract patient year from {weight_folders[i]}. Skipping.")
        continue

    # try:
    #     patient_year = int(patient_year[-4:])
    # except ValueError:
    #     print(f"Warning: Invalid patient year format: {patient_year}. Skipping.")
    #     continue
    
    x.append(f"{patient_id}_{patient_year}")

# %%
# x
from datetime import datetime
from collections import defaultdict

# Step 1: Organize by ID
id_to_dates = defaultdict(list)
for item in x:
    id_part, date_part = item.split('_')
    date_obj = datetime.strptime(date_part, "%m-%d-%Y")
    id_to_dates[id_part].append((date_obj, item))
# print(id_to_dates)

# Step 2: Select earliest date for each ID
unique_patient = [min(dates)[1] for dates in id_to_dates.values()]

len(unique_patient)
# Out:
# 124

# %%
# rf_csv = r"C:\Users\Acer\Desktop\3dVS\RFcsv\volume_data7.csv"
# rf_data = pd.read_csv(rf_csv, index_col=0)
# rf_data

# %%
import os
os.chdir('/home/omen/Documents/Nafisha/VS/VS_refactored_code/newDynUnet')

# %%
from utils.utils import load_spacing, resample_pair, resample_segmentation_to_image
from utils.transformation import transform
from model import DynUNet

# %%
import SimpleITK as sitk
import numpy as np
reader = sitk.ImageSeriesReader()
# from utils.utils import load_spacing, resample_pair

# %%
import matplotlib.pyplot as plt

def plot_image_and_mask(image_data, mask_data, slice_num: int = None, cmap='gray'):

    if slice_num is None:
        slice_num = image_data.shape[0] // 2

    fig, axs = plt.subplots(1, 3, figsize=(15, 5))

    axs[0].imshow(image_data[slice_num,:, :], cmap=cmap)
    axs[0].set_title(f"Image Slice {slice_num}")
    axs[0].axis('off')

    axs[1].imshow(mask_data[slice_num,:, :], cmap=cmap)
    axs[1].set_title(f"Mask Slice {slice_num}")
    axs[1].axis('off')

    axs[2].imshow(image_data[slice_num,:, :], cmap=cmap)
    axs[2].imshow(mask_data[slice_num,:, :], cmap='Reds', alpha=0.4)
    axs[2].set_title(f"Overlay Slice {slice_num}")
    axs[2].axis('off')

    plt.tight_layout()
    plt.show()

# %%
import torch

model= DynUNet(spatial_dims=3,
    in_channels=1,
    out_channels=1,
    kernel_size=[3, 3, 3, 3, 3, 3],
    strides=[1, 2, 2, 2, 2, 2],
    upsample_kernel_size=[2, 2, 2, 2, 2],
    res_block=True,
).to('cuda')

checkpointPath = "/home/omen/Documents/Nafisha/VS/DynUnetCheckpoints/version10.pth"
model.load_state_dict(torch.load(checkpointPath))

# %%
count = 0

learnt_feature_dict = {}
for i in range(len(weight_folders)):
    patient_id = extract_patient_name(weight_folders[i])
    study_date = extract_patient_year(weight_folders[i])
    id_date = f'{patient_id}_{study_date}'

    if id_date in unique_patient:
        # print(id_date)

        dicom_series = reader.GetGDCMSeriesFileNames(weight_folders[i])
        reader.SetFileNames(dicom_series)
        reference_image = reader.Execute()

        segmentation_image = sitk.ReadImage(seg_paths[i])
        segmentation_resampled = resample_segmentation_to_image(segmentation_image, reference_image)

        mask_data = sitk.GetArrayFromImage(segmentation_resampled).astype(np.uint8)
        image_data = sitk.GetArrayFromImage(reference_image).astype(np.float32) 

        spacing = load_spacing(reference_image)
        image_data, mask_data = resample_pair(image_data, mask_data, spacing)

        data_dict = {
            "image": image_data[np.newaxis, ...],  # (1, D, H, W)
            "mask": mask_data[np.newaxis, ...]     # (1, D, H, W)
        }

        transformed = transform(data_dict)

        transformed_image = transformed["image"].unsqueeze(0).to('cuda')
        transformed_mask = transformed["mask"].unsqueeze(0)
        # print(transformed_image.shape, transformed_mask.shape)

        with torch.no_grad():
            encoder_outputs, _ = model(transformed_image)
        learnt_feature = encoder_outputs[-1].squeeze().flatten()

        learnt_feature_dict[patient_id] = learnt_feature
        # print(learnt_feature.shape)
        # break
    if i%10==0:
        print(i)
# Out:
# torch.Size([262144])

# %%
learnt_feature_dict
# Out:
# {'VS-SEG-003': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-010': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-013': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-021': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-025': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-028': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-030': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-031': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-032': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-034': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-041': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-042': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-044': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-045': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-049': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-058': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-059': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-060': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-061': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-070': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-076': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-077': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-082': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-092': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-095': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-098': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-100': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-104': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-107': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-111': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-112': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-116': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-117': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-121': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-122': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-126': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-132': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-133': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-135': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-154': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-164': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-172': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-178': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-188': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-195': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-197': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-199': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-218': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-SEG-221': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-001': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-002': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-004': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-005': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-006': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-007': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-009': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-010': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-011': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-012': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-013': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-015': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-016': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-019': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-020': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-021': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-022': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-024': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-025': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-026': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-027': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-028': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-029': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-030': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-031': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-033': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-035': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-036': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-037': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-038': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-040': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-041': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-043': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-044': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-045': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-046': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-048': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-049': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-052': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-056': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-057': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-058': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-059': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-060': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-062': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-063': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-065': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-067': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-070': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-071': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-072': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-073': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-074': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-076': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-077': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-079': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-080': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-081': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-082': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-083': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-084': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-085': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-086': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-087': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-088': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-093': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-094': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-095': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-096': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-097': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-098': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-099': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-100': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-101': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>),
#  'VS-MC-RC-102': metatensor([-0.0044, -0.0047, -0.0046,  ...,  0.1734, -0.0026,  0.8034],
#         grad_fn=<AliasBackward0>)}

# %%
deep_features = torch.stack(list(learnt_feature_dict.values())).detach().cpu().numpy()
df = pd.DataFrame(deep_features, index=list(learnt_feature_dict.keys()))

# %%
import pandas as pd
volume_data = pd.read_csv('/home/omen/Documents/Nafisha/VS/VS_refactored_code/RandomForest/CSVs/RFselected.csv', index_col=0)
len(volume_data)
# Out:
# (124, 50)

# %%
merged_df = pd.concat([volume_data, df], axis=1)
# Out:
#               volume_diff  change  original_shape_MajorAxisLength  \
# Patient_ID
# VS-MC-RC-001        -51.0       0                       11.098302
# VS-MC-RC-002       1069.0       1                       12.050322
# VS-MC-RC-004     -13391.0       0                       32.442076
# VS-MC-RC-005       2256.0       1                       15.793601
# VS-MC-RC-006        205.0       1                       21.052694
# ...                   ...     ...                             ...
# VS-SEG-195            NaN       0                       11.024049
# VS-SEG-197         1251.0       1                       15.134468
# VS-SEG-199         1102.0       1                       20.328248
# VS-SEG-218         1870.0       1                       24.390526
# VS-SEG-221          602.0       1                       10.943041
#
#               original_shape_Maximum2DDiameterRow  \
# Patient_ID
# VS-MC-RC-001                            10.667506
# VS-MC-RC-002                             8.669793
# VS-MC-RC-004                            33.636311
# VS-MC-RC-005                            15.119270
# VS-MC-RC-006                            14.840822
# ...                                           ...
# VS-SEG-195                               6.088697
# VS-SEG-197                              13.550974
# VS-SEG-199                              20.264196
# VS-SEG-218                              27.083334
# VS-SEG-221                               7.672553
#
#               original_shape_Maximum3DDiameter  original_glcm_Imc1  \
# Patient_ID
# VS-MC-RC-001                         11.824483           -0.055402
# VS-MC-RC-002                         14.842891           -0.147962
# VS-MC-RC-004                         38.487053           -0.402398
# VS-MC-RC-005                         21.244994           -0.084973
# VS-MC-RC-006                         24.568533           -0.100471
# ...                                        ...                 ...
# VS-SEG-195                           11.833204           -0.665496
# VS-SEG-197                           19.078826           -0.083603
# VS-SEG-199                           30.923181           -0.092100
# VS-SEG-218                           31.787093           -0.238635
# VS-SEG-221                           12.477062           -0.142421
#
#               original_glcm_MCC  original_gldm_DependenceNonUniformity  \
# Patient_ID
# VS-MC-RC-001           0.324320                              53.124629
# VS-MC-RC-002           0.454266                             380.436242
# VS-MC-RC-004           0.941602                           16772.235332
# VS-MC-RC-005           0.817496                            3718.285922
# VS-MC-RC-006           0.581540                             815.913548
# ...                         ...                                    ...
# VS-SEG-195             0.974734                             108.379310
# VS-SEG-197             0.490837                             296.263580
# VS-SEG-199             0.519013                            4153.128225
# VS-SEG-218             0.774154                            3271.633887
# VS-SEG-221             0.280022                            2023.210526
#
#               original_glrlm_GrayLevelNonUniformity  \
# Patient_ID
# VS-MC-RC-001                             222.335594
# VS-MC-RC-002                              41.646779
# VS-MC-RC-004                           18344.919598
# VS-MC-RC-005                             397.743860
# VS-MC-RC-006                             976.411879
# ...                                             ...
# VS-SEG-195                                 3.299489
# VS-SEG-197                               136.934265
# VS-SEG-199                              6676.043156
# VS-SEG-218                              8545.320466
# VS-SEG-221                               885.865000
#
#               original_glrlm_RunLengthNonUniformity  \
# Patient_ID
# VS-MC-RC-001                             281.082912
# VS-MC-RC-002                            1070.016494
# VS-MC-RC-004                           94705.574083
# VS-MC-RC-005                           11970.271692
# VS-MC-RC-006                            4895.986528
# ...                                             ...
# VS-SEG-195                               167.773191
# VS-SEG-197                              1598.800575
# VS-SEG-199                             23640.329189
# VS-SEG-218                             11915.651285
# VS-SEG-221                               113.469294
#
#               original_glszm_LargeAreaHighGrayLevelEmphasis  \
# Patient_ID
# VS-MC-RC-001                                   1.741270e+04
# VS-MC-RC-002                                   2.363640e+03
# VS-MC-RC-004                                   3.764821e+08
# VS-MC-RC-005                                   1.321722e+04
# VS-MC-RC-006                                   5.086712e+05
# ...                                                     ...
# VS-SEG-195                                     5.449440e+03
# VS-SEG-197                                     1.087350e+05
# VS-SEG-199                                     2.321828e+06
# VS-SEG-218                                     8.674691e+06
# VS-SEG-221                                     2.082258e+06
#
#               original_ngtdm_Coarseness
# Patient_ID
# VS-MC-RC-001                   0.005272
# VS-MC-RC-002                   0.005885
# VS-MC-RC-004                   0.000073
# VS-MC-RC-005                   0.000656
# VS-MC-RC-006                   0.000963
# ...                                 ...
# VS-SEG-195                     0.023994
# VS-SEG-197                     0.004280
# VS-SEG-199                     0.000146
# VS-SEG-218                     0.000149
# VS-SEG-221                     0.017875
#
# [124 rows x 12 columns]

# %%
dest_path = r'/home/omen/Documents/Nafisha/VS/VS_refactored_code/RandomForest/CSVs/DFcsv.csv'
merged_df.to_csv(dest_path)
